# %% [markdown]
# DS 2002 - Data Project 1
# - Masa Murry & Catherine Choi

# %% [markdown]
# **Part 1. Fetch / download / retrieve a remote data file by URL, or ingest a local file mounted.**

# %%
#1: fetch data source for csv and json
csv_url: "https://www.kaggle.com/datasets/vagifa/worldwide-crop-production"
json_url: "https://www.kaggle.com/datasets/mexwell/crop-diseases-classification?resource=download"

# %% [markdown]
# **Part 2. Convert the general format and data structure of the data source and take user input to choose file format**
# *   CSV to JSON to SQL
# *   JSON to CSV to SQL

# %%
#2a: csv to json to sql

import pandas as pd
import sqlite3
dfa = pd.read_csv('worldwide_crop_consumption.csv')

# user input to choose file format (csv/json/sql)
answer= input()
if answer == 'csv':
    dfa.to_csv('worldwide_crop_consumption.csv')
    display(dfa)
elif answer == 'json':
    dfa.to_json('worldwide_crop_consumption.json')
    display(dfa)
elif answer == 'sql':
    dfa.to_sql('worldwide_crop_consumption.sql', con=sqlite3.connect('worldwide_crop_consumption.sql'))
    print(dfa)
else:
    print('Invalid input')
# Out:
# json
#       LOCATION  SUBJECT   MEASURE  TIME     Value
# 0          AUS     RICE  TONNE_HA  1990  5.374114
# 1          AUS     RICE  TONNE_HA  1991  5.897753
# 2          AUS     RICE  TONNE_HA  1992  5.903150
# 3          AUS     RICE  TONNE_HA  1993  5.221311
# 4          AUS     RICE  TONNE_HA  1994  5.457576
# ...        ...      ...       ...   ...       ...
# 21160     EU28  SOYBEAN  TONNE_HA  2022  2.897405
# 21161     EU28  SOYBEAN  TONNE_HA  2023  2.903548
# 21162     EU28  SOYBEAN  TONNE_HA  2024  2.915203
# 21163     EU28  SOYBEAN  TONNE_HA  2025  2.919959
# 21164     EU28  SOYBEAN  TONNE_HA  2026  2.930918
#
# [21165 rows x 5 columns]

# %%
#2b: json to csv to sql

import pandas as pd
import sqlite3
# Add 'lines=True' to handle JSON with multiple objects
dfb = pd.read_json('label_num_to_disease_map.json', lines=True)

# user input to choose file format (csv/json/sql)
answer= input()
if answer == 'csv':
    dfb.to_csv('label_num_to_disease_map.json', index=False) # Add index=False to avoid writing index
    display(dfb)
elif answer == 'json':
    dfb.to_json('label_num_to_disease_map.json', orient='records', lines=True) # Use orient='records' and lines=True for consistent output
    display(dfb)
elif answer == 'sql':
    dfb.to_sql('label_num_to_disease_map.json', con=sqlite3.connect('label_num_to_disease_map.sql'))
else:
    print('Invalid input')
# Out:
# csv
#                                 0                                    1  \
# 0  Cassava Bacterial Blight (CBB)  Cassava Brown Streak Disease (CBSD)
#
#                             2                             3        4
# 0  Cassava Green Mottle (CGM)  Cassava Mosaic Disease (CMD)  Healthy

# %% [markdown]
# **Part 3. Modify the number of columns from the source to the destination, reducing or adding columns.**
# - 3a: adding a column to the csv
# - 3b: adding a column to the json
#
# **Part 5: Included in the following code. Generate a brief summary of the data file ingestion including:**
# 1. Number of records
# 2. Number of columns
#
# **Part 6: Included in the following code. Generate a brief summary of the post processing including:**
# 1. Number of records
# 2. Number of columns

# %%
#3a: make changes to csv , add column

def modify_columns(dfa):

    #5: brief summary of the data file - rows and columns
    print(f"Original Columns: {dfa.columns.tolist()}")
    print(f"Pre-modification: {dfa.shape[0]} rows, {dfa.shape[1]} columns")

    try:
        dfa['Needs_Watering'] = 'Yes'
        print("Added 'Needs_Watering' column with default value 'Yes'.")
    except Exception as e:
        print(f"Error: {e}")

    #6: brief summary of the data post-processing - rows and columns
    print(f"Modified Columns: {list(dfa.columns)}")
    print(f"Post-modification: {dfa.shape[0]} rows, {dfa.shape[1]} columns\n")
    return dfa

dfa = modify_columns(dfa)
dfa.head()
# Out:
# Original Columns: ['LOCATION', 'SUBJECT', 'MEASURE', 'TIME', 'Value']
# Pre-modification: 21165 rows, 5 columns
# Added 'Needs_Watering' column with default value 'Yes'.
# Modified Columns: ['LOCATION', 'SUBJECT', 'MEASURE', 'TIME', 'Value', 'Needs_Watering']
# Post-modification: 21165 rows, 6 columns
#   LOCATION SUBJECT   MEASURE  TIME     Value Needs_Watering
# 0      AUS    RICE  TONNE_HA  1990  5.374114            Yes
# 1      AUS    RICE  TONNE_HA  1991  5.897753            Yes
# 2      AUS    RICE  TONNE_HA  1992  5.903150            Yes
# 3      AUS    RICE  TONNE_HA  1993  5.221311            Yes
# 4      AUS    RICE  TONNE_HA  1994  5.457576            Yes

# %%
#3b: make changes to json , add column

def modify_columns(dfb):

    #5: brief summary of the data file - rows and columns
    print(f"Original Columns: {dfb.columns.tolist()}")
    print(f"Pre-modification: {dfb.shape[0]} rows, {dfb.shape[1]} columns")

    try:
        dfb['5'] = 'Bacterial Leaf Blight of Rice (BLB)'
        print("Added '5' column with default value 'Bacterial Leaf Blight of Rice (BLB)'.")
    except Exception as e:
        print(f"Error: {e}")

    #6: brief summary of the data post-processing - rows and columns
    print(f"Modified Columns: {list(dfb.columns)}")
    print(f"Post-modification: {dfb.shape[0]} rows, {dfb.shape[1]} columns\n")
    return dfb

dfb = modify_columns(dfb)
dfb.head()
# Out:
# Original Columns: [0, 1, 2, 3, 4]
# Pre-modification: 1 rows, 5 columns
# Added '5' column with default value 'Bacterial Leaf Blight of Rice (BLB)'.
# Modified Columns: [0, 1, 2, 3, 4, '5']
# Post-modification: 1 rows, 6 columns
#                                 0                                    1  \
# 0  Cassava Bacterial Blight (CBB)  Cassava Brown Streak Disease (CBSD)
#
#                             2                             3        4  \
# 0  Cassava Green Mottle (CGM)  Cassava Mosaic Disease (CMD)  Healthy
#
#                                      5
# 0  Bacterial Leaf Blight of Rice (BLB)

# %% [markdown]
# **Part 4: The converted (new) file is written to a SQL database.**

# %%
#4: store new file to sql database

with sqlite3.connect('/content/modified_data.db') as conn:
    # saves the modified dataframe (dfa) of the worldwide_crop_consumption to a merged database
    dfa.to_sql('modified_data', conn, if_exists='replace', index=False)
    print("Saved to SQLite database.")
    # saves the modified dataframe (dfb) of the label_num_to_disease_map to a merged database
    dfb.to_sql('modified_data', conn, if_exists='replace', index=False)
    print("Saved to SQLite database.")
# Out:
# Saved to SQLite database.
# Saved to SQLite database.
